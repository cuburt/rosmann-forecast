# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, cross_val_score
import math
import seaborn as sns
import xgboost as xgb
from skopt import BayesSearchCV
# %matplotlib inline

# %%
df = pd.read_csv('train.csv', index_col='Date', parse_dates=True, low_memory=False)
df.sort_values(by='Date', inplace=True)

# %%
store = pd.read_csv('store.csv', low_memory=False)

# %%
train = df[0:math.ceil(df.shape[0]*0.8)]
test = df[train.shape[0]:df.shape[0]]

# %%
test.tail()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2015-04-30    746          4   9469        748     1      1            0
# 2015-04-30    747          4  12123       1017     1      1            0
# 2015-04-30    748          4   9524        746     1      1            0
# 2015-04-30    742          4  12225       1196     1      1            0
# 2015-04-30      1          4   6228        650     1      1            0
#
#             SchoolHoliday
# Date
# 2015-04-30              0
# 2015-04-30              0
# 2015-04-30              0
# 2015-04-30              0
# 2015-04-30              0

# %%
train.tail()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2014-11-09    156          7      0          0     0      0            0
# 2014-11-09    154          7      0          0     0      0            0
# 2014-11-09    153          7      0          0     0      0            0
# 2014-11-09    152          7      0          0     0      0            0
# 2014-11-09    151          7      0          0     0      0            0
#
#             SchoolHoliday
# Date
# 2014-11-09              0
# 2014-11-09              0
# 2014-11-09              0
# 2014-11-09              0
# 2014-11-09              0

# %%
train.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
# x_train[pd.isnull(x_train.Open)]

# %%
# x_train.fillna(1, inplace = True)

# %%
train['Year'] = train.index.year
train['Month'] = train.index.month
train['Day'] = train.index.day
train['WeekOfYear'] = train.index.weekofyear


train['SalePerCustomer'] = train['Sales']/train['Customers']
train['SalePerCustomer'].describe()
# Out:
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1638829526.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Year'] = train.index.year
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1638829526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Month'] = train.index.month
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1638829526.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Day'] = train.index.day
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1638829526.py:4: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   train['WeekOfYear'] = train.index.weekofyear
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1638829526.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['WeekOfYear'] = train.index.weekofyear
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1638829526.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['SalePerCustomer'] = train['Sales']/train['Customers']
# count    608007.000000
# mean          9.366660
# std           2.160887
# min           0.000000
# 25%           7.798910
# 50%           9.125214
# 75%          10.751448
# max          64.957854
# Name: SalePerCustomer, dtype: float64

# %%
train[(train.Open == 0) & (train.Sales == 0)].head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2013-01-01   1115          2      0          0     0      0            a
# 2013-01-01    379          2      0          0     0      0            a
# 2013-01-01    378          2      0          0     0      0            a
# 2013-01-01    377          2      0          0     0      0            a
# 2013-01-01    376          2      0          0     0      0            a
#
#             SchoolHoliday  Year  Month  Day  WeekOfYear  SalePerCustomer
# Date
# 2013-01-01              1  2013      1    1           1              NaN
# 2013-01-01              1  2013      1    1           1              NaN
# 2013-01-01              1  2013      1    1           1              NaN
# 2013-01-01              1  2013      1    1           1              NaN
# 2013-01-01              1  2013      1    1           1              NaN

# %%
zero_sales = train[(train.Open != 0) & (train.Sales == 0)]
print("In total: ", zero_sales.shape)
zero_sales.head(5)
# Out:
# In total:  (51, 13)
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2013-01-17    762          4      0          0     1      0            0
# 2013-01-24    232          4      0          0     1      1            0
# 2013-01-30    339          3      0          0     1      0            0
# 2013-01-31    339          4      0          0     1      0            0
# 2013-02-07    259          4      0          0     1      1            0
#
#             SchoolHoliday  Year  Month  Day  WeekOfYear  SalePerCustomer
# Date
# 2013-01-17              0  2013      1   17           3              NaN
# 2013-01-24              0  2013      1   24           4              NaN
# 2013-01-30              0  2013      1   30           5              NaN
# 2013-01-31              0  2013      1   31           5              NaN
# 2013-02-07              0  2013      2    7           6              NaN

# %%
store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store[pd.isnull(store.CompetitionDistance)]
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a                  NaN
# 621    622         a          c                  NaN
# 878    879         d          a                  NaN
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        NaN                       NaN       0
# 621                        NaN                       NaN       0
# 878                        NaN                       NaN       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              NaN              NaN              NaN
# 621              NaN              NaN              NaN
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %%
# fill NaN with a median value (skewed distribuion)
store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace = True)

# %%
_ = store[pd.isnull(store.Promo2SinceWeek)]
_[_.Promo2 != 0].shape
# Out:
# (0, 10)

# %%
store.fillna(0, inplace = True)

# %%
print("Joining train set with an additional store information.")

# by specifying inner join we make sure that only those observations 
# that are present in both train and store sets are merged together
train.reset_index(inplace=True)
train_store = pd.merge(train, store, how = 'inner', on = 'Store')

print("In total: ", train_store.shape)
# train_store.drop(columns='index')
# Out:
# Joining train set with an additional store information.
# In total:  (731704, 23)

# %%
train_store
# Out:
#              Date  Store  DayOfWeek  Sales  Customers  Open  Promo  \
# 0      2013-01-01   1115          2      0          0     0      0
# 1      2013-01-02   1115          3   3697        305     1      0
# 2      2013-01-03   1115          4   4297        300     1      0
# 3      2013-01-04   1115          5   4540        326     1      0
# 4      2013-01-05   1115          6   4771        339     1      0
# ...           ...    ...        ...    ...        ...   ...    ...
# 731699 2014-11-04    988          2   5095        753     1      1
# 731700 2014-11-05    988          3   4334        682     1      1
# 731701 2014-11-06    988          4   5127        776     1      1
# 731702 2014-11-07    988          5   4890        723     1      1
# 731703 2014-11-08    988          6   3444        545     1      0
#
#        StateHoliday  SchoolHoliday  Year  ...  SalePerCustomer  StoreType  \
# 0                 a              1  2013  ...              NaN          d
# 1                 0              1  2013  ...        12.121311          d
# 2                 0              1  2013  ...        14.323333          d
# 3                 0              1  2013  ...        13.926380          d
# 4                 0              1  2013  ...        14.073746          d
# ...             ...            ...   ...  ...              ...        ...
# 731699            0              0  2014  ...         6.766268          a
# 731700            0              0  2014  ...         6.354839          a
# 731701            0              0  2014  ...         6.606959          a
# 731702            0              0  2014  ...         6.763485          a
# 731703            0              0  2014  ...         6.319266          a
#
#         Assortment  CompetitionDistance CompetitionOpenSinceMonth  \
# 0                c               5350.0                       0.0
# 1                c               5350.0                       0.0
# 2                c               5350.0                       0.0
# 3                c               5350.0                       0.0
# 4                c               5350.0                       0.0
# ...            ...                  ...                       ...
# 731699           a                 30.0                      11.0
# 731700           a                 30.0                      11.0
# 731701           a                 30.0                      11.0
# 731702           a                 30.0                      11.0
# 731703           a                 30.0                      11.0
#
#        CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                           0.0       1             22.0           2012.0
# 1                           0.0       1             22.0           2012.0
# 2                           0.0       1             22.0           2012.0
# 3                           0.0       1             22.0           2012.0
# 4                           0.0       1             22.0           2012.0
# ...                         ...     ...              ...              ...
# 731699                   2012.0       0              0.0              0.0
# 731700                   2012.0       0              0.0              0.0
# 731701                   2012.0       0              0.0              0.0
# 731702                   2012.0       0              0.0              0.0
# 731703                   2012.0       0              0.0              0.0
#
#            PromoInterval
# 0       Mar,Jun,Sept,Dec
# 1       Mar,Jun,Sept,Dec
# 2       Mar,Jun,Sept,Dec
# 3       Mar,Jun,Sept,Dec
# 4       Mar,Jun,Sept,Dec
# ...                  ...
# 731699                 0
# 731700                 0
# 731701                 0
# 731702                 0
# 731703                 0
#
# [731704 rows x 23 columns]

# %%
train_store.groupby('StoreType')['Sales'].describe()
# Out:
#               count         mean          std  min     25%     50%      75%  \
# StoreType
# a          396792.0  5671.162092  3920.836667  0.0  3467.0  5541.0   7763.0
# b           11386.0  9731.467240  5287.243950  0.0  5941.0  8727.0  12681.0
# c           98418.0  5626.267725  3667.966523  0.0  3716.0  5667.0   7705.0
# d          225108.0  5521.770923  3396.095491  0.0  3903.0  5700.0   7525.0
#
#                max
# StoreType
# a          38025.0
# b          37403.0
# c          31448.0
# d          38037.0

# %%
train_store.groupby('StoreType')['Customers', 'Sales'].sum()
# Out:
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\3647216997.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   train_store.groupby('StoreType')['Customers', 'Sales'].sum()
#            Customers       Sales
# StoreType
# a          261931727  2250271749
# b           22214451   110802486
# c           66030011   553726017
# d          112039992  1242994809

# %%
sns.catplot(x="Month", y="Sales", hue="StoreType",col="Promo", kind="point", data=train_store)

# %%
sns.catplot(x="Month", y="Customers", hue="StoreType",col="Promo", kind="point", data=train_store)

# %%
sns.catplot(x="Month", y="SalePerCustomer", hue="StoreType",col="Promo", kind="point", data=train_store)

# %%
sns.catplot(x="Month", y="Sales", hue="StoreType",col="DayOfWeek", kind="point", data=train_store)

# %%
train_store[(train_store.Open == 1) & (train_store.DayOfWeek == 7)]['Store'].unique()
# Out:
# array([ 353,  310,  299,  335,  512,  494,  524,  530,  433,  423,  453,
#          85,  122,  209,  274,  262,  259,  931,  948,  867,  863,  877,
#        1099, 1097, 1081, 1045,  682,  676,  578,  562,  769,  732,  733],
#       dtype=int64)

# %%
# competition open time (in months)
train_store['CompetitionOpen'] = 12 * (train_store.Year - train_store.CompetitionOpenSinceYear) + (train_store.Month - train_store.CompetitionOpenSinceMonth)

# Promo open time
train_store['PromoOpen'] = 12 * (train_store.Year - train_store.Promo2SinceYear) + (train_store.WeekOfYear - train_store.Promo2SinceWeek) / 4.0

# replace NA's by 0
train_store.fillna(0, inplace = True)

# average PromoOpen time and CompetitionOpen time per store type
train_store.loc[:, ['StoreType', 'Sales', 'Customers', 'PromoOpen', 'CompetitionOpen']].groupby('StoreType').mean()
# Out:
#                  Sales    Customers     PromoOpen  CompetitionOpen
# StoreType
# a          5671.162092   660.123508  12876.017206      7118.232855
# b          9731.467240  1951.032057  17256.876273     11262.425698
# c          5626.267725   670.913969  12122.397928      6734.934311
# d          5521.770923   497.716616  10391.375736      9033.309274

# %%
# Compute the correlation matrix 
# exclude 'Open' variable
corr_all = train_store.drop('Open', axis = 1).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr_all, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize = (11, 9))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_all, mask = mask,
            square = True, linewidths = .5, ax = ax, cmap = "BuPu")      
plt.show()
# Out:
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1075848621.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr_all, dtype = np.bool)

# %%
sns.catplot(x="DayOfWeek", y="Sales", hue="Promo2",col="Promo",row="Promo2", kind="point", data=train_store)

# %%
# plt.figure(figsize=(100,10))
df_copy = train_store.copy()
df_copy.set_index('Date', inplace=True)

# %%
df_copy.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2013-01-01   1115          2      0          0     0      0            a
# 2013-01-02   1115          3   3697        305     1      0            0
# 2013-01-03   1115          4   4297        300     1      0            0
# 2013-01-04   1115          5   4540        326     1      0            0
# 2013-01-05   1115          6   4771        339     1      0            0
#
#             SchoolHoliday  Year  Month  ...  Assortment  CompetitionDistance  \
# Date                                    ...
# 2013-01-01              1  2013      1  ...           c               5350.0
# 2013-01-02              1  2013      1  ...           c               5350.0
# 2013-01-03              1  2013      1  ...           c               5350.0
# 2013-01-04              1  2013      1  ...           c               5350.0
# 2013-01-05              1  2013      1  ...           c               5350.0
#
#             CompetitionOpenSinceMonth CompetitionOpenSinceYear Promo2  \
# Date
# 2013-01-01                        0.0                      0.0      1
# 2013-01-02                        0.0                      0.0      1
# 2013-01-03                        0.0                      0.0      1
# 2013-01-04                        0.0                      0.0      1
# 2013-01-05                        0.0                      0.0      1
#
#             Promo2SinceWeek  Promo2SinceYear     PromoInterval  \
# Date
# 2013-01-01             22.0           2012.0  Mar,Jun,Sept,Dec
# 2013-01-02             22.0           2012.0  Mar,Jun,Sept,Dec
# 2013-01-03             22.0           2012.0  Mar,Jun,Sept,Dec
# 2013-01-04             22.0           2012.0  Mar,Jun,Sept,Dec
# 2013-01-05             22.0           2012.0  Mar,Jun,Sept,Dec
#
#             CompetitionOpen  PromoOpen
# Date
# 2013-01-01          24157.0       6.75
# 2013-01-02          24157.0       6.75
# 2013-01-03          24157.0       6.75
# 2013-01-04          24157.0       6.75
# 2013-01-05          24157.0       6.75
#
# [5 rows x 24 columns]

# %%
ave_df = pd.DataFrame(df_copy.Sales.resample('D').mean())

# %%
ave_df.head()
# Out:
#                   Sales
# Date
# 2013-01-01    87.284560
# 2013-01-02  6233.030493
# 2013-01-03  5693.112108
# 2013-01-04  5954.218834
# 2013-01-05  5337.751570

# %%
# for i in [x for x in train_store['StoreType'].values]:
#     df_copy = df_copy.loc[df_copy.StoreType == i]
#     ave_df = pd.DataFrame(df_copy.Sales.resample('D').mean())

#     plt.plot(ave_df.Sales)
# plt.title('Rossmann Sales')
# plt.ylabel('Sales')

# %%
test.head()
# Out:
#             Store  DayOfWeek  Sales  Customers  Open  Promo StateHoliday  \
# Date
# 2014-11-09    150          7      0          0     0      0            0
# 2014-11-09    148          7      0          0     0      0            0
# 2014-11-09    147          7      0          0     0      0            0
# 2014-11-09    146          7      0          0     0      0            0
# 2014-11-09    178          7      0          0     0      0            0
#
#             SchoolHoliday
# Date
# 2014-11-09              0
# 2014-11-09              0
# 2014-11-09              0
# 2014-11-09              0
# 2014-11-09              0

# %%
test.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
# test[pd.isnull(test.Open)]
# test.fillna(1, inplace = True)

# %%
# data extraction
test['Year'] = test.index.year
test['Month'] = test.index.month
test['Day'] = test.index.day
test['WeekOfYear'] = test.index.weekofyear

# to numerical
mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
test.StateHoliday.replace(mappings, inplace = True)

train_store.Assortment.replace(mappings, inplace = True)
train_store.StoreType.replace(mappings, inplace = True)
train_store.StateHoliday.replace(mappings, inplace = True)
train_store.drop('PromoInterval', axis = 1, inplace = True)

store.StoreType.replace(mappings, inplace = True)
store.Assortment.replace(mappings, inplace = True)
store.drop('PromoInterval', axis = 1, inplace = True)
# Out:
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1691009162.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Year'] = test.index.year
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1691009162.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Month'] = test.index.month
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1691009162.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Day'] = test.index.day
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1691009162.py:5: FutureWarning: weekofyear and week have been deprecated, please use DatetimeIndex.isocalendar().week instead, which returns a Series.  To exactly reproduce the behavior of week and weekofyear and return an Index, you may call pd.Int64Index(idx.isocalendar().week)
#   test['WeekOfYear'] = test.index.weekofyear
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\1691009162.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['WeekOfYear'] = test.index.weekofyear
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
print("Joining test set with an additional store information.")
test_store = pd.merge(test, store, how = 'inner', on = 'Store')

test_store['CompetitionOpen'] = 12 * (test_store.Year - test_store.CompetitionOpenSinceYear) + (test_store.Month - test_store.CompetitionOpenSinceMonth)
test_store['PromoOpen'] = 12 * (test_store.Year - test_store.Promo2SinceYear) + (test_store.WeekOfYear - test_store.Promo2SinceWeek) / 4.0

print("In total: ", test_store.shape)
test_store.head()
# Out:
# Joining test set with an additional store information.
# In total:  (182925, 22)
#    Store  DayOfWeek  Sales  Customers  Open  Promo  StateHoliday  \
# 0    150          7      0          0     0      0             0
# 1    150          1  10960       1017     1      1             0
# 2    150          2   8649        787     1      1             0
# 3    150          3   8854        823     1      1             0
# 4    150          4   9117        844     1      1             0
#
#    SchoolHoliday  Year  Month  ...  StoreType  Assortment  \
# 0              0  2014     11  ...          3           3
# 1              0  2014     11  ...          3           3
# 2              0  2014     11  ...          3           3
# 3              0  2014     11  ...          3           3
# 4              0  2014     11  ...          3           3
#
#    CompetitionDistance  CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0              31830.0                        3.0                    2010.0
# 1              31830.0                        3.0                    2010.0
# 2              31830.0                        3.0                    2010.0
# 3              31830.0                        3.0                    2010.0
# 4              31830.0                        3.0                    2010.0
#
#    Promo2  Promo2SinceWeek  Promo2SinceYear  CompetitionOpen  PromoOpen
# 0       0              0.0              0.0             56.0   24179.25
# 1       0              0.0              0.0             56.0   24179.50
# 2       0              0.0              0.0             56.0   24179.50
# 3       0              0.0              0.0             56.0   24179.50
# 4       0              0.0              0.0             56.0   24179.50
#
# [5 rows x 22 columns]

# %%
# split into training and evaluation sets
# excluding Sales and Id columns\
# train_store.drop(columns="Date", inplace=True)
train_store['Sales'] = train_store['Sales'] * 1.0
test['Sales'] = test['Sales'] * 1.0
predictors = [x for x in train_store.columns if x in ['Store', 'DayOfWeek', 'Customers', 'Day', 'Month', 'Year', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday']]
y = train_store.Sales # log transformation of Sales
X = train_store

# split the data into train/test set
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.2, # 30% for the evaluation set
                                                    random_state = 42)
# Out:
# C:\Users\cuburt.balanon\AppData\Local\Temp\ipykernel_36484\869725172.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Sales'] = test['Sales'] * 1.0

# %%
y_train
# Out:
# 568187     4654.0
# 621543     5055.0
# 206045     9713.0
# 378669     5630.0
# 395637     4757.0
#            ...
# 259178     9339.0
# 365838    24523.0
# 131932     9804.0
# 671155     4677.0
# 121958     6893.0
# Name: Sales, Length: 585363, dtype: float64

# %%
# evaluation metric: rmspe
# Root Mean Square Percentage Error
# code chunk shared at Kaggle

def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat / y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y, yhat)

# %%
# base parameters
params = {
    'booster': 'gbtree', 
    'objective': 'reg:linear', # regression task
    'subsample': 0.8, # 80% of data to grow trees and prevent overfitting
    'colsample_bytree': 0.85, # 85% of features used
    'eta': 0.05, 
    'max_depth': 10, 
    'seed': 42} # for reproducible results

# %%
X_train[predictors].head()
# Out:
#         Store  DayOfWeek  Customers  Open  Promo  StateHoliday  SchoolHoliday  \
# 568187    631          6        599     1      0             0              0
# 621543    618          4        399     1      1             0              0
# 206045    104          3       1295     1      1             0              1
# 378669    920          6        571     1      0             0              0
# 395637    963          6        451     1      0             0              0
#
#         Year  Month  Day
# 568187  2013     12   28
# 621543  2013      2    7
# 206045  2013      6   19
# 378669  2013     12    7
# 395637  2013     12   28

# %%
# # XGB with xgboost library
# dtrain = xgb.DMatrix(X_train[predictors], y_train)
# dtest = xgb.DMatrix(X_test[predictors], y_test)

# watchlist = [(dtrain, 'train'), (dtest, 'test')]

# xgb_model = xgb.train(params, dtrain, 300, evals = watchlist,
#                       early_stopping_rounds = 50, feval = rmspe_xg, verbose_eval = True)

# %%
initial_model = xgb.XGBRegressor()

# %%
parameters = { 'nthread':[4], #when use hyperthread, xgboost may become slower
                                    'objective':['reg:linear'],
                                    'learning_rate': [.03, 0.05, .07], 
                                    'max_depth': [5, 6, 7],
                                    'min_child_weight': [4],
                                    'silent': [1],
                                    'subsample': [0.7],
                                    'colsample_bytree': [0.7],
                                    'n_estimators': [500]}

# %%
def get_tuned_model(X_train_data, X_test_data, y_train_data, y_test_data,
                       model, param_grid, cv=5, scoring_fit='neg_mean_squared_error',
                   do_probabilities = False):

        """ Tuned parameter for regression algorithms (ex: XGBoost model (Regressor) ) """
        bo = BayesSearchCV(model, param_grid, cv=cv, n_jobs=-1, scoring=scoring_fit, verbose=2)
                    
        # gs = GridSearchCV(
        #     estimator=model,
        #     param_grid=param_grid, 
        #     cv=cv, 
        #     n_jobs=-1, 
        #     scoring=scoring_fit,
        #     verbose=2
        # )
        fitted_model = bo.fit(X_train_data, y_train_data)

        #if do_probabilities:
        #   pred = fitted_model.predict_proba(X_test_data)
        #else:
        pred = fitted_model.predict(X_test_data)

        return fitted_model, pred

# %%
cv, scoring_fit = 5, 'neg_mean_squared_error'
tuned_model, pred = get_tuned_model(X_train[predictors], X_test[predictors], y_train, y_test, initial_model, parameters, cv, scoring_fit)
best_params = tuned_model.best_params_

model = xgb.XGBRegressor(objective = 'reg:squarederror',
           colsample_bytree = best_params["colsample_bytree"],
           learning_rate = best_params["learning_rate"],
           max_depth = best_params["max_depth"],
           min_child_weight = best_params["min_child_weight"],
           n_estimators = best_params["n_estimators"],
           subsample = best_params["subsample"])
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\skopt\optimizer\optimizer.py:463: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [23:42:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [23:42:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# ########################## fit the model #####################
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 15>()
#       5 model = xgb.XGBRegressor(objective = 'reg:squarederror',
#       6            colsample_bytree = best_params["colsample_bytree"],
#       7            learning_rate = best_params["learning_rate"],
#    (...)
#      10            n_estimators = best_params["n_estimators"],
#      11            subsample = best_params["subsample"])
#      13 print("########################## fit the model #####################")
# ---> 15 model.fit(X_train[predictors], y_train, eval_metric='rmse', eval_set=evalset)
#      16 score = model.score(X_train[predictors], y_train)
#      17 print(f"Training score: {score}")
#
# NameError: name 'evalset' is not defined

# %%
model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.07, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=500, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
import os
import joblib
from pathlib import Path

local_model_storage_path = os.path.join("model_storage", f"rosmann.sav")
Path(local_model_storage_path).parent.mkdir(parents=True, exist_ok=True)
joblib.dump(model, local_model_storage_path)
# Out:
# ['model_storage\\rosmann.sav']

# %%
rosmann_model = joblib.load(local_model_storage_path)

# %%
rosmann_model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.7,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.07, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=4,
#              missing=nan, monotone_constraints='()', n_estimators=500, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
evalset = [(X_train[predictors], y_train), (X_test[predictors],y_test)]
print("########################## fit the model #####################")

model.fit(X_train[predictors], y_train, eval_metric='rmse', eval_set=evalset)
score = model.score(X_train[predictors], y_train)  
print(f"Training score: {score}")

print("########################## Cross-Validation #####################")

cross_validation_score = cross_val_score(model, X_train[predictors], y_train, cv=5)
print(f"Mean cross-validation score:, {cross_validation_score.mean()}")
# Out:
# ########################## fit the model #####################
# C:\Users\cuburt.balanon\Anaconda3\envs\regression\lib\site-packages\xgboost\sklearn.py:793: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:6370.95357	validation_1-rmse:6386.83296
# [1]	validation_0-rmse:5947.65125	validation_1-rmse:5962.62531
# [2]	validation_0-rmse:5552.72602	validation_1-rmse:5566.97055
# [3]	validation_0-rmse:5228.11143	validation_1-rmse:5242.65744
# [4]	validation_0-rmse:4886.60933	validation_1-rmse:4900.42636
# [5]	validation_0-rmse:4571.95797	validation_1-rmse:4585.21001
# [6]	validation_0-rmse:4313.05879	validation_1-rmse:4326.46464
# [7]	validation_0-rmse:4094.46792	validation_1-rmse:4108.04760
# [8]	validation_0-rmse:3837.33789	validation_1-rmse:3850.37401
# [9]	validation_0-rmse:3633.76951	validation_1-rmse:3647.02567
# [10]	validation_0-rmse:3411.98661	validation_1-rmse:3424.77589
# [11]	validation_0-rmse:3239.28685	validation_1-rmse:3252.35703
# [12]	validation_0-rmse:3048.89791	validation_1-rmse:3061.73413
# [13]	validation_0-rmse:2873.00295	validation_1-rmse:2885.68918
# [14]	validation_0-rmse:2712.11180	validation_1-rmse:2724.39934
# [15]	validation_0-rmse:2590.81795	validation_1-rmse:2603.23335
# [16]	validation_0-rmse:2480.94622	validation_1-rmse:2493.53895
# [17]	validation_0-rmse:2382.95474	validation_1-rmse:2395.87300
# [18]	validation_0-rmse:2263.02776	validation_1-rmse:2275.52171
# [19]	validation_0-rmse:2152.95608	validation_1-rmse:2165.22019
# [20]	validation_0-rmse:2052.90979	validation_1-rmse:2064.96987
# [21]	validation_0-rmse:1984.17476	validation_1-rmse:1996.41228
# [22]	validation_0-rmse:1899.78153	validation_1-rmse:1911.79903
# [23]	validation_0-rmse:1823.00903	validation_1-rmse:1834.93392
# [24]	validation_0-rmse:1752.90224	validation_1-rmse:1764.56706
# [25]	validation_0-rmse:1690.33494	validation_1-rmse:1701.84461
# [26]	validation_0-rmse:1635.81911	validation_1-rmse:1647.22387
# [27]	validation_0-rmse:1583.87771	validation_1-rmse:1595.26241
# [28]	validation_0-rmse:1537.14475	validation_1-rmse:1548.42269
# [29]	validation_0-rmse:1497.63444	validation_1-rmse:1508.91384
# [30]	validation_0-rmse:1462.58279	validation_1-rmse:1473.85276
# [31]	validation_0-rmse:1431.70432	validation_1-rmse:1443.03409
# [32]	validation_0-rmse:1401.26073	validation_1-rmse:1412.60232
# [33]	validation_0-rmse:1383.51638	validation_1-rmse:1394.98129
# [34]	validation_0-rmse:1361.05748	validation_1-rmse:1372.43041
# [35]	validation_0-rmse:1335.08405	validation_1-rmse:1346.39026
# [36]	validation_0-rmse:1317.96792	validation_1-rmse:1329.23861
# [37]	validation_0-rmse:1297.06498	validation_1-rmse:1308.27115
# [38]	validation_0-rmse:1286.69280	validation_1-rmse:1297.86237
# [39]	validation_0-rmse:1270.81670	validation_1-rmse:1281.92001
# [40]	validation_0-rmse:1262.66979	validation_1-rmse:1273.74264
# [41]	validation_0-rmse:1252.49815	validation_1-rmse:1263.60128
# [42]	validation_0-rmse:1238.44581	validation_1-rmse:1249.89692
# [43]	validation_0-rmse:1233.02640	validation_1-rmse:1244.41511
# [44]	validation_0-rmse:1225.82993	validation_1-rmse:1237.26153
# [45]	validation_0-rmse:1219.43478	validation_1-rmse:1230.89269
# [46]	validation_0-rmse:1214.85046	validation_1-rmse:1226.33876
# [47]	validation_0-rmse:1205.42499	validation_1-rmse:1216.79810
# [48]	validation_0-rmse:1202.14330	validation_1-rmse:1213.49650
# [49]	validation_0-rmse:1198.52234	validation_1-rmse:1209.86778
# [50]	validation_0-rmse:1195.95227	validation_1-rmse:1207.23024
# [51]	validation_0-rmse:1186.70520	validation_1-rmse:1198.01362
# [52]	validation_0-rmse:1183.25221	validation_1-rmse:1194.62700
# [53]	validation_0-rmse:1173.10158	validation_1-rmse:1184.61881
# [54]	validation_0-rmse:1170.40453	validation_1-rmse:1181.94287
# [55]	validation_0-rmse:1162.98290	validation_1-rmse:1174.45744
# [56]	validation_0-rmse:1160.62419	validation_1-rmse:1172.10724
# [57]	validation_0-rmse:1158.43079	validation_1-rmse:1169.92087
# [58]	validation_0-rmse:1156.33724	validation_1-rmse:1167.87380
# [59]	validation_0-rmse:1150.47794	validation_1-rmse:1161.61547
# [60]	validation_0-rmse:1148.93235	validation_1-rmse:1160.10916
# [61]	validation_0-rmse:1139.93287	validation_1-rmse:1151.14981
# [62]	validation_0-rmse:1136.82168	validation_1-rmse:1148.04619
# [63]	validation_0-rmse:1135.53131	validation_1-rmse:1146.81485
# [64]	validation_0-rmse:1134.43280	validation_1-rmse:1145.72204
# [65]	validation_0-rmse:1132.00185	validation_1-rmse:1143.36869
# [66]	validation_0-rmse:1126.91545	validation_1-rmse:1138.39091
# [67]	validation_0-rmse:1122.90038	validation_1-rmse:1134.44354
# [68]	validation_0-rmse:1117.77993	validation_1-rmse:1129.36157
# [69]	validation_0-rmse:1116.00875	validation_1-rmse:1127.57308
# [70]	validation_0-rmse:1115.14666	validation_1-rmse:1126.74194
# [71]	validation_0-rmse:1108.81128	validation_1-rmse:1120.47857
# [72]	validation_0-rmse:1107.94328	validation_1-rmse:1119.61768
# [73]	validation_0-rmse:1107.24166	validation_1-rmse:1118.99526
# [74]	validation_0-rmse:1106.57260	validation_1-rmse:1118.34267
# [75]	validation_0-rmse:1104.77160	validation_1-rmse:1116.59548
# [76]	validation_0-rmse:1099.03450	validation_1-rmse:1110.74718
# [77]	validation_0-rmse:1098.31341	validation_1-rmse:1110.16024
# [78]	validation_0-rmse:1097.68289	validation_1-rmse:1109.61902
# [79]	validation_0-rmse:1092.34074	validation_1-rmse:1104.57571
# [80]	validation_0-rmse:1091.80196	validation_1-rmse:1104.04449
# [81]	validation_0-rmse:1090.90849	validation_1-rmse:1103.14753
# [82]	validation_0-rmse:1085.31323	validation_1-rmse:1097.66611
# [83]	validation_0-rmse:1084.12488	validation_1-rmse:1096.47053
# [84]	validation_0-rmse:1083.65898	validation_1-rmse:1096.02375
# [85]	validation_0-rmse:1076.83928	validation_1-rmse:1089.45234
# [86]	validation_0-rmse:1071.38435	validation_1-rmse:1084.07134
# [87]	validation_0-rmse:1070.86020	validation_1-rmse:1083.59499
# [88]	validation_0-rmse:1065.34928	validation_1-rmse:1078.30946
# [89]	validation_0-rmse:1064.93891	validation_1-rmse:1077.93541
# [90]	validation_0-rmse:1064.63817	validation_1-rmse:1077.69312
# [91]	validation_0-rmse:1062.85173	validation_1-rmse:1075.97765
# [92]	validation_0-rmse:1062.21561	validation_1-rmse:1075.37509
# [93]	validation_0-rmse:1057.38062	validation_1-rmse:1070.37730
# [94]	validation_0-rmse:1055.92511	validation_1-rmse:1069.05370
# [95]	validation_0-rmse:1054.28353	validation_1-rmse:1067.47366
# [96]	validation_0-rmse:1051.05472	validation_1-rmse:1064.34549
# [97]	validation_0-rmse:1050.72180	validation_1-rmse:1064.00535
# [98]	validation_0-rmse:1047.76909	validation_1-rmse:1061.18207
# [99]	validation_0-rmse:1046.18607	validation_1-rmse:1059.55794
# [100]	validation_0-rmse:1045.91931	validation_1-rmse:1059.34696
# [101]	validation_0-rmse:1044.31426	validation_1-rmse:1057.84611
# [102]	validation_0-rmse:1043.93697	validation_1-rmse:1057.53049
# [103]	validation_0-rmse:1040.64047	validation_1-rmse:1054.22101
# [104]	validation_0-rmse:1040.23654	validation_1-rmse:1053.86290
# [105]	validation_0-rmse:1035.61234	validation_1-rmse:1049.34093
# [106]	validation_0-rmse:1034.25729	validation_1-rmse:1048.03393
# [107]	validation_0-rmse:1034.00932	validation_1-rmse:1047.82655
# [108]	validation_0-rmse:1033.53225	validation_1-rmse:1047.35048
# [109]	validation_0-rmse:1031.78226	validation_1-rmse:1045.59546
# [110]	validation_0-rmse:1025.80000	validation_1-rmse:1039.62742
# [111]	validation_0-rmse:1025.44341	validation_1-rmse:1039.34847
# [112]	validation_0-rmse:1024.58457	validation_1-rmse:1038.49452
# [113]	validation_0-rmse:1024.25001	validation_1-rmse:1038.21972
# [114]	validation_0-rmse:1023.98850	validation_1-rmse:1038.00523
# [115]	validation_0-rmse:1020.07926	validation_1-rmse:1034.11730
# [116]	validation_0-rmse:1016.83176	validation_1-rmse:1030.68694
# [117]	validation_0-rmse:1010.34755	validation_1-rmse:1024.16659
# [118]	validation_0-rmse:1006.53453	validation_1-rmse:1020.27478
# [119]	validation_0-rmse:1006.33839	validation_1-rmse:1020.12128
# [120]	validation_0-rmse:1002.14658	validation_1-rmse:1015.89116
# [121]	validation_0-rmse:1001.42463	validation_1-rmse:1015.16644
# [122]	validation_0-rmse:995.90460	validation_1-rmse:1009.58756
# [123]	validation_0-rmse:992.02142	validation_1-rmse:1005.71416
# [124]	validation_0-rmse:987.04033	validation_1-rmse:1000.68691
# [125]	validation_0-rmse:981.85506	validation_1-rmse:995.60167
# [126]	validation_0-rmse:981.57228	validation_1-rmse:995.37002
# [127]	validation_0-rmse:980.31790	validation_1-rmse:994.17213
# [128]	validation_0-rmse:977.06158	validation_1-rmse:990.99662
# [129]	validation_0-rmse:975.44168	validation_1-rmse:989.36787
# [130]	validation_0-rmse:972.70406	validation_1-rmse:986.69585
# [131]	validation_0-rmse:968.07041	validation_1-rmse:982.02650
# [132]	validation_0-rmse:963.18358	validation_1-rmse:977.17607
# [133]	validation_0-rmse:962.79817	validation_1-rmse:976.85242
# [134]	validation_0-rmse:962.11454	validation_1-rmse:976.17235
# [135]	validation_0-rmse:960.67216	validation_1-rmse:974.77472
# [136]	validation_0-rmse:960.33729	validation_1-rmse:974.48561
# [137]	validation_0-rmse:960.11221	validation_1-rmse:974.26022
# [138]	validation_0-rmse:954.94910	validation_1-rmse:969.18867
# [139]	validation_0-rmse:954.63287	validation_1-rmse:968.88672
# [140]	validation_0-rmse:954.48104	validation_1-rmse:968.80418
# [141]	validation_0-rmse:953.90827	validation_1-rmse:968.23154
# [142]	validation_0-rmse:949.24121	validation_1-rmse:963.59925
# [143]	validation_0-rmse:948.66843	validation_1-rmse:963.02753
# [144]	validation_0-rmse:947.37295	validation_1-rmse:961.75945
# [145]	validation_0-rmse:945.70208	validation_1-rmse:960.07712
# [146]	validation_0-rmse:945.20203	validation_1-rmse:959.60028
# [147]	validation_0-rmse:943.29727	validation_1-rmse:957.76537
# [148]	validation_0-rmse:941.25350	validation_1-rmse:955.84943
# [149]	validation_0-rmse:941.07498	validation_1-rmse:955.68194
# [150]	validation_0-rmse:937.35991	validation_1-rmse:951.96443
# [151]	validation_0-rmse:934.42849	validation_1-rmse:949.07363
# [152]	validation_0-rmse:933.22069	validation_1-rmse:947.82983
# [153]	validation_0-rmse:932.59768	validation_1-rmse:947.23074
# [154]	validation_0-rmse:929.98707	validation_1-rmse:944.68572
# [155]	validation_0-rmse:926.28295	validation_1-rmse:940.98039
# [156]	validation_0-rmse:923.45609	validation_1-rmse:938.04615
# [157]	validation_0-rmse:923.30361	validation_1-rmse:937.92468
# [158]	validation_0-rmse:921.86903	validation_1-rmse:936.50540
# [159]	validation_0-rmse:921.52144	validation_1-rmse:936.14044
# [160]	validation_0-rmse:919.26199	validation_1-rmse:933.87733
# [161]	validation_0-rmse:918.92653	validation_1-rmse:933.52774
# [162]	validation_0-rmse:914.85212	validation_1-rmse:929.41620
# [163]	validation_0-rmse:914.58965	validation_1-rmse:929.17670
# [164]	validation_0-rmse:911.69270	validation_1-rmse:926.32299
# [165]	validation_0-rmse:907.72071	validation_1-rmse:922.46088
# [166]	validation_0-rmse:907.13126	validation_1-rmse:921.92163
# [167]	validation_0-rmse:906.59685	validation_1-rmse:921.42247
# [168]	validation_0-rmse:904.28643	validation_1-rmse:919.18997
# [169]	validation_0-rmse:901.23057	validation_1-rmse:916.13023
# [170]	validation_0-rmse:897.84719	validation_1-rmse:912.79518
# [171]	validation_0-rmse:896.65528	validation_1-rmse:911.57787
# [172]	validation_0-rmse:893.30485	validation_1-rmse:908.30518
# [173]	validation_0-rmse:893.13413	validation_1-rmse:908.17854
# [174]	validation_0-rmse:892.73060	validation_1-rmse:907.77335
# [175]	validation_0-rmse:892.49828	validation_1-rmse:907.52937
# [176]	validation_0-rmse:888.74531	validation_1-rmse:903.76087
# [177]	validation_0-rmse:887.43637	validation_1-rmse:902.43769
# [178]	validation_0-rmse:885.07210	validation_1-rmse:900.05912
# [179]	validation_0-rmse:883.92329	validation_1-rmse:898.92023
# [180]	validation_0-rmse:881.99743	validation_1-rmse:897.03899
# [181]	validation_0-rmse:881.25063	validation_1-rmse:896.26599
# [182]	validation_0-rmse:881.07669	validation_1-rmse:896.11620
# [183]	validation_0-rmse:880.90794	validation_1-rmse:895.97741
# [184]	validation_0-rmse:880.46616	validation_1-rmse:895.52678
# [185]	validation_0-rmse:877.27408	validation_1-rmse:892.35534
# [186]	validation_0-rmse:875.92466	validation_1-rmse:891.06220
# [187]	validation_0-rmse:872.87378	validation_1-rmse:888.04018
# [188]	validation_0-rmse:872.23986	validation_1-rmse:887.36965
# [189]	validation_0-rmse:868.68539	validation_1-rmse:883.87534
# [190]	validation_0-rmse:868.36300	validation_1-rmse:883.56744
# [191]	validation_0-rmse:864.53941	validation_1-rmse:879.70170
# [192]	validation_0-rmse:863.21188	validation_1-rmse:878.39588
# [193]	validation_0-rmse:863.07139	validation_1-rmse:878.27827
# [194]	validation_0-rmse:862.37587	validation_1-rmse:877.61180
# [195]	validation_0-rmse:859.36033	validation_1-rmse:874.60518
# [196]	validation_0-rmse:857.82189	validation_1-rmse:873.12049
# [197]	validation_0-rmse:856.24901	validation_1-rmse:871.66569
# [198]	validation_0-rmse:854.93807	validation_1-rmse:870.32663
# [199]	validation_0-rmse:854.77049	validation_1-rmse:870.20142
# [200]	validation_0-rmse:853.01805	validation_1-rmse:868.46777
# [201]	validation_0-rmse:851.44157	validation_1-rmse:866.89600
# [202]	validation_0-rmse:848.78331	validation_1-rmse:864.28547
# [203]	validation_0-rmse:848.56433	validation_1-rmse:864.07471
# [204]	validation_0-rmse:847.07498	validation_1-rmse:862.61879
# [205]	validation_0-rmse:844.55946	validation_1-rmse:860.19566
# [206]	validation_0-rmse:843.14376	validation_1-rmse:858.82580
# [207]	validation_0-rmse:843.00729	validation_1-rmse:858.73030
# [208]	validation_0-rmse:841.45633	validation_1-rmse:857.16289
# [209]	validation_0-rmse:839.36236	validation_1-rmse:855.05867
# [210]	validation_0-rmse:837.05925	validation_1-rmse:852.78993
# [211]	validation_0-rmse:836.58666	validation_1-rmse:852.34569
# [212]	validation_0-rmse:836.44501	validation_1-rmse:852.23758
# [213]	validation_0-rmse:836.35974	validation_1-rmse:852.17880
# [214]	validation_0-rmse:836.25831	validation_1-rmse:852.12942
# [215]	validation_0-rmse:835.14204	validation_1-rmse:851.00394
# [216]	validation_0-rmse:832.71071	validation_1-rmse:848.54836
# [217]	validation_0-rmse:832.55726	validation_1-rmse:848.39170
# [218]	validation_0-rmse:830.58979	validation_1-rmse:846.47599
# [219]	validation_0-rmse:828.98112	validation_1-rmse:844.95207
# [220]	validation_0-rmse:827.07133	validation_1-rmse:843.02172
# [221]	validation_0-rmse:824.78002	validation_1-rmse:840.75166
# [222]	validation_0-rmse:824.61118	validation_1-rmse:840.57233
# [223]	validation_0-rmse:822.46742	validation_1-rmse:838.43526
# [224]	validation_0-rmse:822.19851	validation_1-rmse:838.15937
# [225]	validation_0-rmse:822.13195	validation_1-rmse:838.10140
# [226]	validation_0-rmse:822.06024	validation_1-rmse:838.04545
# [227]	validation_0-rmse:821.97776	validation_1-rmse:837.98142
# [228]	validation_0-rmse:821.90173	validation_1-rmse:837.92799
# [229]	validation_0-rmse:821.83942	validation_1-rmse:837.88863
# [230]	validation_0-rmse:821.76671	validation_1-rmse:837.83900
# [231]	validation_0-rmse:820.60147	validation_1-rmse:836.72191
# [232]	validation_0-rmse:818.37865	validation_1-rmse:834.51705
# [233]	validation_0-rmse:817.22763	validation_1-rmse:833.39496
# [234]	validation_0-rmse:815.41108	validation_1-rmse:831.63160
# [235]	validation_0-rmse:815.16022	validation_1-rmse:831.37193
# [236]	validation_0-rmse:815.06402	validation_1-rmse:831.32428
# [237]	validation_0-rmse:812.68174	validation_1-rmse:829.04927
# [238]	validation_0-rmse:811.19317	validation_1-rmse:827.55706
# [239]	validation_0-rmse:810.92208	validation_1-rmse:827.30297
# [240]	validation_0-rmse:810.28173	validation_1-rmse:826.66104
# [241]	validation_0-rmse:809.81443	validation_1-rmse:826.23651
# [242]	validation_0-rmse:809.72145	validation_1-rmse:826.18560
# [243]	validation_0-rmse:808.41143	validation_1-rmse:824.88466
# [244]	validation_0-rmse:808.00723	validation_1-rmse:824.45311
# [245]	validation_0-rmse:806.75729	validation_1-rmse:823.17964
# [246]	validation_0-rmse:806.64042	validation_1-rmse:823.10368
# [247]	validation_0-rmse:806.55205	validation_1-rmse:823.06288
# [248]	validation_0-rmse:804.41649	validation_1-rmse:820.92710
# [249]	validation_0-rmse:803.34285	validation_1-rmse:819.90365
# [250]	validation_0-rmse:803.10870	validation_1-rmse:819.66234
# [251]	validation_0-rmse:801.12329	validation_1-rmse:817.67058
# [252]	validation_0-rmse:799.61810	validation_1-rmse:816.19945
# [253]	validation_0-rmse:799.43656	validation_1-rmse:816.02112
# [254]	validation_0-rmse:797.58307	validation_1-rmse:814.17070
# [255]	validation_0-rmse:797.43118	validation_1-rmse:814.01111
# [256]	validation_0-rmse:796.40091	validation_1-rmse:812.99625
# [257]	validation_0-rmse:796.25411	validation_1-rmse:812.87608
# [258]	validation_0-rmse:794.13474	validation_1-rmse:810.69992
# [259]	validation_0-rmse:794.07682	validation_1-rmse:810.66623
# [260]	validation_0-rmse:791.94812	validation_1-rmse:808.52587
# [261]	validation_0-rmse:790.08206	validation_1-rmse:806.74072
# [262]	validation_0-rmse:789.96867	validation_1-rmse:806.65510
# [263]	validation_0-rmse:789.04243	validation_1-rmse:805.73637
# [264]	validation_0-rmse:788.73828	validation_1-rmse:805.44002
# [265]	validation_0-rmse:788.62575	validation_1-rmse:805.32198
# [266]	validation_0-rmse:788.56698	validation_1-rmse:805.30399
# [267]	validation_0-rmse:786.70048	validation_1-rmse:803.44119
# [268]	validation_0-rmse:785.45555	validation_1-rmse:802.14508
# [269]	validation_0-rmse:784.74622	validation_1-rmse:801.41399
# [270]	validation_0-rmse:783.57562	validation_1-rmse:800.24998
# [271]	validation_0-rmse:781.95386	validation_1-rmse:798.67322
# [272]	validation_0-rmse:780.23636	validation_1-rmse:796.97396
# [273]	validation_0-rmse:778.14372	validation_1-rmse:794.94111
# [274]	validation_0-rmse:775.77385	validation_1-rmse:792.67012
# [275]	validation_0-rmse:775.68203	validation_1-rmse:792.57140
# [276]	validation_0-rmse:774.66232	validation_1-rmse:791.55960
# [277]	validation_0-rmse:773.64220	validation_1-rmse:790.57725
# [278]	validation_0-rmse:773.50570	validation_1-rmse:790.44204
# [279]	validation_0-rmse:772.50315	validation_1-rmse:789.45648
# [280]	validation_0-rmse:770.75719	validation_1-rmse:787.70913
# [281]	validation_0-rmse:770.01329	validation_1-rmse:786.97674
# [282]	validation_0-rmse:769.52584	validation_1-rmse:786.48607
# [283]	validation_0-rmse:769.43856	validation_1-rmse:786.42921
# [284]	validation_0-rmse:767.92048	validation_1-rmse:784.95836
# [285]	validation_0-rmse:766.70896	validation_1-rmse:783.73734
# [286]	validation_0-rmse:766.66897	validation_1-rmse:783.72004
# [287]	validation_0-rmse:765.67783	validation_1-rmse:782.77276
# [288]	validation_0-rmse:765.58574	validation_1-rmse:782.70529
# [289]	validation_0-rmse:764.79320	validation_1-rmse:781.93792
# [290]	validation_0-rmse:763.34450	validation_1-rmse:780.52579
# [291]	validation_0-rmse:763.14159	validation_1-rmse:780.31594
# [292]	validation_0-rmse:762.29861	validation_1-rmse:779.49184
# [293]	validation_0-rmse:761.73655	validation_1-rmse:778.92818
# [294]	validation_0-rmse:760.72081	validation_1-rmse:777.90822
# [295]	validation_0-rmse:758.63490	validation_1-rmse:775.94322
# [296]	validation_0-rmse:757.20207	validation_1-rmse:774.49012
# [297]	validation_0-rmse:756.45604	validation_1-rmse:773.76342
# [298]	validation_0-rmse:754.63525	validation_1-rmse:772.06143
# [299]	validation_0-rmse:754.46634	validation_1-rmse:771.88241
# [300]	validation_0-rmse:753.14191	validation_1-rmse:770.54461
# [301]	validation_0-rmse:752.81437	validation_1-rmse:770.24087
# [302]	validation_0-rmse:752.72623	validation_1-rmse:770.18550
# [303]	validation_0-rmse:752.03410	validation_1-rmse:769.49271
# [304]	validation_0-rmse:751.94802	validation_1-rmse:769.45484
# [305]	validation_0-rmse:751.87751	validation_1-rmse:769.41570
# [306]	validation_0-rmse:751.82823	validation_1-rmse:769.38742
# [307]	validation_0-rmse:750.18010	validation_1-rmse:767.75556
# [308]	validation_0-rmse:748.05646	validation_1-rmse:765.66756
# [309]	validation_0-rmse:747.40509	validation_1-rmse:764.99994
# [310]	validation_0-rmse:746.06792	validation_1-rmse:763.74406
# [311]	validation_0-rmse:745.98271	validation_1-rmse:763.68278
# [312]	validation_0-rmse:745.92903	validation_1-rmse:763.67281
# [313]	validation_0-rmse:745.00369	validation_1-rmse:762.75661
# [314]	validation_0-rmse:743.39971	validation_1-rmse:761.16005
# [315]	validation_0-rmse:743.33354	validation_1-rmse:761.12736
# [316]	validation_0-rmse:741.72044	validation_1-rmse:759.46149
# [317]	validation_0-rmse:741.67198	validation_1-rmse:759.42086
# [318]	validation_0-rmse:740.11317	validation_1-rmse:757.86981
# [319]	validation_0-rmse:739.30006	validation_1-rmse:757.05658
# [320]	validation_0-rmse:739.25739	validation_1-rmse:757.03906
# [321]	validation_0-rmse:738.09708	validation_1-rmse:755.91832
# [322]	validation_0-rmse:736.85324	validation_1-rmse:754.74814
# [323]	validation_0-rmse:736.35058	validation_1-rmse:754.25337
# [324]	validation_0-rmse:736.27248	validation_1-rmse:754.23425
# [325]	validation_0-rmse:734.87951	validation_1-rmse:752.83121
# [326]	validation_0-rmse:734.06796	validation_1-rmse:752.04183
# [327]	validation_0-rmse:732.06453	validation_1-rmse:750.10661
# [328]	validation_0-rmse:730.91466	validation_1-rmse:748.95139
# [329]	validation_0-rmse:730.85005	validation_1-rmse:748.89688
# [330]	validation_0-rmse:729.70674	validation_1-rmse:747.71301
# [331]	validation_0-rmse:728.55035	validation_1-rmse:746.60164
# [332]	validation_0-rmse:728.38872	validation_1-rmse:746.43350
# [333]	validation_0-rmse:727.29779	validation_1-rmse:745.32645
# [334]	validation_0-rmse:726.51294	validation_1-rmse:744.54997
# [335]	validation_0-rmse:725.80525	validation_1-rmse:743.87398
# [336]	validation_0-rmse:724.30493	validation_1-rmse:742.35354
# [337]	validation_0-rmse:724.26472	validation_1-rmse:742.35287
# [338]	validation_0-rmse:723.33895	validation_1-rmse:741.40825
# [339]	validation_0-rmse:723.10205	validation_1-rmse:741.16070
# [340]	validation_0-rmse:721.81991	validation_1-rmse:739.89763
# [341]	validation_0-rmse:720.49452	validation_1-rmse:738.64319
# [342]	validation_0-rmse:719.04550	validation_1-rmse:737.23287
# [343]	validation_0-rmse:717.47360	validation_1-rmse:735.69609
# [344]	validation_0-rmse:717.36682	validation_1-rmse:735.58428
# [345]	validation_0-rmse:716.55825	validation_1-rmse:734.81600
# [346]	validation_0-rmse:715.48717	validation_1-rmse:733.74266
# [347]	validation_0-rmse:714.78567	validation_1-rmse:733.05872
# [348]	validation_0-rmse:712.63843	validation_1-rmse:730.94260
# [349]	validation_0-rmse:712.57471	validation_1-rmse:730.89752
# [350]	validation_0-rmse:712.49340	validation_1-rmse:730.81766
# [351]	validation_0-rmse:712.25657	validation_1-rmse:730.60540
# [352]	validation_0-rmse:712.13496	validation_1-rmse:730.48263
# [353]	validation_0-rmse:712.08038	validation_1-rmse:730.46057
# [354]	validation_0-rmse:711.07652	validation_1-rmse:729.48010
# [355]	validation_0-rmse:709.49537	validation_1-rmse:727.99502
# [356]	validation_0-rmse:707.78149	validation_1-rmse:726.33035
# [357]	validation_0-rmse:706.71024	validation_1-rmse:725.27703
# [358]	validation_0-rmse:705.93723	validation_1-rmse:724.50435
# [359]	validation_0-rmse:705.85822	validation_1-rmse:724.43784
# [360]	validation_0-rmse:704.69334	validation_1-rmse:723.29063
# [361]	validation_0-rmse:703.02263	validation_1-rmse:721.62793
# [362]	validation_0-rmse:701.74546	validation_1-rmse:720.41008
# [363]	validation_0-rmse:701.62818	validation_1-rmse:720.31667
# [364]	validation_0-rmse:701.53097	validation_1-rmse:720.21721
# [365]	validation_0-rmse:700.48777	validation_1-rmse:719.18722
# [366]	validation_0-rmse:700.39443	validation_1-rmse:719.15152
# [367]	validation_0-rmse:700.31550	validation_1-rmse:719.13772
# [368]	validation_0-rmse:699.77669	validation_1-rmse:718.61924
# [369]	validation_0-rmse:698.54984	validation_1-rmse:717.42101
# [370]	validation_0-rmse:697.15803	validation_1-rmse:716.07470
# [371]	validation_0-rmse:697.00588	validation_1-rmse:715.92056
# [372]	validation_0-rmse:696.67737	validation_1-rmse:715.58129
# [373]	validation_0-rmse:695.31443	validation_1-rmse:714.27563
# [374]	validation_0-rmse:695.22425	validation_1-rmse:714.19998
# [375]	validation_0-rmse:694.58563	validation_1-rmse:713.56277
# [376]	validation_0-rmse:693.55366	validation_1-rmse:712.51090
# [377]	validation_0-rmse:693.36316	validation_1-rmse:712.30238
# [378]	validation_0-rmse:691.96384	validation_1-rmse:711.00181
# [379]	validation_0-rmse:691.91858	validation_1-rmse:710.96803
# [380]	validation_0-rmse:690.27772	validation_1-rmse:709.46085
# [381]	validation_0-rmse:689.37880	validation_1-rmse:708.57556
# [382]	validation_0-rmse:689.31364	validation_1-rmse:708.54945
# [383]	validation_0-rmse:688.03149	validation_1-rmse:707.37149
# [384]	validation_0-rmse:686.22358	validation_1-rmse:705.61256
# [385]	validation_0-rmse:685.43311	validation_1-rmse:704.80110
# [386]	validation_0-rmse:684.12128	validation_1-rmse:703.59950
# [387]	validation_0-rmse:682.94145	validation_1-rmse:702.46713
# [388]	validation_0-rmse:681.94279	validation_1-rmse:701.45785
# [389]	validation_0-rmse:681.88764	validation_1-rmse:701.41388
# [390]	validation_0-rmse:681.73855	validation_1-rmse:701.26191
# [391]	validation_0-rmse:680.95374	validation_1-rmse:700.47431
# [392]	validation_0-rmse:680.10971	validation_1-rmse:699.65423
# [393]	validation_0-rmse:680.02349	validation_1-rmse:699.58204
# [394]	validation_0-rmse:678.94272	validation_1-rmse:698.58128
# [395]	validation_0-rmse:678.21054	validation_1-rmse:697.88034
# [396]	validation_0-rmse:678.12119	validation_1-rmse:697.78217
# [397]	validation_0-rmse:677.24547	validation_1-rmse:696.96170
# [398]	validation_0-rmse:676.50964	validation_1-rmse:696.27302
# [399]	validation_0-rmse:675.43366	validation_1-rmse:695.24037
# [400]	validation_0-rmse:675.36586	validation_1-rmse:695.21423
# [401]	validation_0-rmse:674.01011	validation_1-rmse:693.92734
# [402]	validation_0-rmse:672.67086	validation_1-rmse:692.59303
# [403]	validation_0-rmse:672.60799	validation_1-rmse:692.54198
# [404]	validation_0-rmse:672.55480	validation_1-rmse:692.52439
# [405]	validation_0-rmse:671.06652	validation_1-rmse:691.06204
# [406]	validation_0-rmse:669.52057	validation_1-rmse:689.61997
# [407]	validation_0-rmse:668.29915	validation_1-rmse:688.41869
# [408]	validation_0-rmse:668.23783	validation_1-rmse:688.36413
# [409]	validation_0-rmse:667.10125	validation_1-rmse:687.27984
# [410]	validation_0-rmse:667.05622	validation_1-rmse:687.24921
# [411]	validation_0-rmse:666.23548	validation_1-rmse:686.42350
# [412]	validation_0-rmse:666.12257	validation_1-rmse:686.33006
# [413]	validation_0-rmse:666.02282	validation_1-rmse:686.27626
# [414]	validation_0-rmse:665.46953	validation_1-rmse:685.73683
# [415]	validation_0-rmse:664.58438	validation_1-rmse:684.86231
# [416]	validation_0-rmse:663.85809	validation_1-rmse:684.19301
# [417]	validation_0-rmse:663.23723	validation_1-rmse:683.58458
# [418]	validation_0-rmse:663.19632	validation_1-rmse:683.54122
# [419]	validation_0-rmse:663.15149	validation_1-rmse:683.51332
# [420]	validation_0-rmse:662.34806	validation_1-rmse:682.78042
# [421]	validation_0-rmse:661.38740	validation_1-rmse:681.86133
# [422]	validation_0-rmse:660.62370	validation_1-rmse:681.06941
# [423]	validation_0-rmse:660.55405	validation_1-rmse:681.04331
# [424]	validation_0-rmse:659.90598	validation_1-rmse:680.40776
# [425]	validation_0-rmse:658.90429	validation_1-rmse:679.45274
# [426]	validation_0-rmse:657.43612	validation_1-rmse:678.03859
# [427]	validation_0-rmse:656.89797	validation_1-rmse:677.51328
# [428]	validation_0-rmse:656.04075	validation_1-rmse:676.67916
# [429]	validation_0-rmse:655.12855	validation_1-rmse:675.79272
# [430]	validation_0-rmse:655.06444	validation_1-rmse:675.74169
# [431]	validation_0-rmse:654.99887	validation_1-rmse:675.68505
# [432]	validation_0-rmse:653.84886	validation_1-rmse:674.58344
# [433]	validation_0-rmse:653.72976	validation_1-rmse:674.46253
# [434]	validation_0-rmse:653.27564	validation_1-rmse:674.01451
# [435]	validation_0-rmse:652.80153	validation_1-rmse:673.57671
# [436]	validation_0-rmse:652.15115	validation_1-rmse:672.92601
# [437]	validation_0-rmse:650.50831	validation_1-rmse:671.32376
# [438]	validation_0-rmse:650.44580	validation_1-rmse:671.27629
# [439]	validation_0-rmse:649.39377	validation_1-rmse:670.23135
# [440]	validation_0-rmse:649.09128	validation_1-rmse:669.94970
# [441]	validation_0-rmse:647.93207	validation_1-rmse:668.84412
# [442]	validation_0-rmse:647.67675	validation_1-rmse:668.63097
# [443]	validation_0-rmse:647.54103	validation_1-rmse:668.49253
# [444]	validation_0-rmse:647.49232	validation_1-rmse:668.44868
# [445]	validation_0-rmse:646.44722	validation_1-rmse:667.40189
# [446]	validation_0-rmse:646.36725	validation_1-rmse:667.34420
# [447]	validation_0-rmse:645.76021	validation_1-rmse:666.74147
# [448]	validation_0-rmse:645.59025	validation_1-rmse:666.59480
# [449]	validation_0-rmse:645.20343	validation_1-rmse:666.21564
# [450]	validation_0-rmse:644.50026	validation_1-rmse:665.52624
# [451]	validation_0-rmse:644.05341	validation_1-rmse:665.08809
# [452]	validation_0-rmse:643.46970	validation_1-rmse:664.55692
# [453]	validation_0-rmse:642.97955	validation_1-rmse:664.06911
# [454]	validation_0-rmse:642.91649	validation_1-rmse:664.02884
# [455]	validation_0-rmse:642.83934	validation_1-rmse:664.02338
# [456]	validation_0-rmse:641.84397	validation_1-rmse:663.03150
# [457]	validation_0-rmse:641.19938	validation_1-rmse:662.38477
# [458]	validation_0-rmse:640.80430	validation_1-rmse:661.99914
# [459]	validation_0-rmse:639.72287	validation_1-rmse:660.96243
# [460]	validation_0-rmse:638.19551	validation_1-rmse:659.49403
# [461]	validation_0-rmse:638.11605	validation_1-rmse:659.41035
# [462]	validation_0-rmse:637.25340	validation_1-rmse:658.56649
# [463]	validation_0-rmse:636.57694	validation_1-rmse:657.91324
# [464]	validation_0-rmse:635.70872	validation_1-rmse:657.06783
# [465]	validation_0-rmse:635.65568	validation_1-rmse:657.04968
# [466]	validation_0-rmse:634.76983	validation_1-rmse:656.14998
# [467]	validation_0-rmse:634.18543	validation_1-rmse:655.50799
# [468]	validation_0-rmse:633.34100	validation_1-rmse:654.70801
# [469]	validation_0-rmse:633.29792	validation_1-rmse:654.69256
# [470]	validation_0-rmse:633.23158	validation_1-rmse:654.67541
# [471]	validation_0-rmse:632.29803	validation_1-rmse:653.76985
# [472]	validation_0-rmse:632.16238	validation_1-rmse:653.62495
# [473]	validation_0-rmse:631.61660	validation_1-rmse:653.14881
# [474]	validation_0-rmse:630.83002	validation_1-rmse:652.39013
# [475]	validation_0-rmse:630.75389	validation_1-rmse:652.33099
# [476]	validation_0-rmse:630.12807	validation_1-rmse:651.73741
# [477]	validation_0-rmse:630.07719	validation_1-rmse:651.72029
# [478]	validation_0-rmse:629.37648	validation_1-rmse:651.03074
# [479]	validation_0-rmse:628.86707	validation_1-rmse:650.56625
# [480]	validation_0-rmse:628.65123	validation_1-rmse:650.38519
# [481]	validation_0-rmse:627.44949	validation_1-rmse:649.22278
# [482]	validation_0-rmse:626.57995	validation_1-rmse:648.40263
# [483]	validation_0-rmse:625.61878	validation_1-rmse:647.44103
# [484]	validation_0-rmse:624.69714	validation_1-rmse:646.53324
# [485]	validation_0-rmse:624.64327	validation_1-rmse:646.51838
# [486]	validation_0-rmse:624.54929	validation_1-rmse:646.42127
# [487]	validation_0-rmse:624.47884	validation_1-rmse:646.42438
# [488]	validation_0-rmse:623.97711	validation_1-rmse:645.93204
# [489]	validation_0-rmse:623.89675	validation_1-rmse:645.90625
# [490]	validation_0-rmse:623.20716	validation_1-rmse:645.23898
# [491]	validation_0-rmse:623.15565	validation_1-rmse:645.23756
# [492]	validation_0-rmse:623.10934	validation_1-rmse:645.22837
# [493]	validation_0-rmse:622.82691	validation_1-rmse:644.95165
# [494]	validation_0-rmse:622.52692	validation_1-rmse:644.63775
# [495]	validation_0-rmse:622.48047	validation_1-rmse:644.62324
# [496]	validation_0-rmse:621.93852	validation_1-rmse:644.09197
# [497]	validation_0-rmse:621.19916	validation_1-rmse:643.37121
# [498]	validation_0-rmse:621.13251	validation_1-rmse:643.30727
# [499]	validation_0-rmse:621.07281	validation_1-rmse:643.24676
# Training score: 0.9731696576412623
# ########################## Cross-Validation #####################
# Mean cross-validation score:, 0.9700127548378061
# ########################## Model-Prediction #####################
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 15>()
#      13 print("########################## Model-Prediction #####################")
#      14 ypred = model.predict(X_test[predictors])
# ---> 15 error_msg = self.regression_metrics(y_test, ypred, metrics_path)
#      17 print(f"Error error_msg {error_msg}")
#      19 print("#################################### RESULTS PLOTTING  START ####################")
#
# NameError: name 'self' is not defined

# %%
from sklearn.metrics import (accuracy_score, classification_report,
                             confusion_matrix, mean_absolute_error,
                             mean_absolute_percentage_error,
                             mean_squared_error, mean_squared_log_error,
                             r2_score, roc_auc_score, roc_curve)
import json
def regression_metrics(y_test, y_pred, metrics_path):

    """Evalutation metrics for regression models."""
    errorsmsg = ""
    try:
        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        mae = mean_absolute_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred, multioutput='variance_weighted')
        mean_absolute_percentage_error_score = mean_absolute_percentage_error(y_test.tolist(),
                                                                              y_pred.tolist())

        print("R2:  %.2f" % r2)
        print("Mean Squared Error: %.2f" % mse)
        print("Root Mean Squared Error: %.2f" % rmse)
        print("Mean Absolute Error:  %.2f" % mae)
        print("Mean Absolute Percentage Error:  %.2f" % mean_absolute_percentage_error_score)

        mlpipeline_metrics = {"metrics":[{"name":"R2", "numberValue":r2, "format":"RAW"},
                {"name":"Mean Squared Error", "numberValue":mse, "format":"RAW"},
                {"name":"Root Mean Squared Error", "numberValue":rmse, "format":"RAW"},
                {"name":"Mean Absolute Error","numberValue":mae, "format":"RAW"},
                 {"name":"Mean Absolute Percentage Error","numberValue":mean_absolute_percentage_error_score, "format":"RAW"}]}

        Path(metrics_path).parent.mkdir(parents=True, exist_ok=True)        

        with open(metrics_path, "w") as f1:
            json.dump(mlpipeline_metrics, f1)

    except Exception as e:
        print(str(e))
        errorsmsg = str(e)
    return errorsmsg

# %%
local_metrics_storage_path = "metrics_storage"

# %%
print("########################## Model-Prediction #####################")
ypred = model.predict(X_test[predictors])
error_msg = regression_metrics(y_test, ypred, local_metrics_storage_path)

print("#################################### RESULTS PLOTTING  START ####################")
if not error_msg:
    x_ax = range(len(y_test))
    plt.rcParams["figure.figsize"] = (30, 7)
    plt.plot(x_ax, y_test, label="original")
    plt.plot(x_ax, ypred, label="predicted")
    plt.title("Sales test and predicted data")
    plt.legend()
    plt.show()
    xgb.plot_importance(model, max_num_features = 15)
    plt.show()
print("####################################RESULTS PLOTTING END ####################")
# Out:
# ########################## Model-Prediction #####################
# R2:  0.97
# Mean Squared Error: 413766.40
# Root Mean Squared Error: 643.25
# Mean Absolute Error:  438.98
# Mean Absolute Percentage Error:  85374846496098192.00
# #################################### RESULTS PLOTTING  START ####################
# ####################################RESULTS PLOTTING END ####################

# %%
request = {
"Store": 1111,
"DayOfWeek": 4,
"Date": "2014-07-10",
"Customers": 410,
"Open": 1,
"Promo": 0,
"StateHoliday": "0",
"SchoolHoliday": 1
}

# %%
X_train
# Out:
#              Date  Store  DayOfWeek    Sales  Customers  Open  Promo  \
# 568187 2013-12-28    631          6   4654.0        599     1      0
# 621543 2013-02-07    618          4   5055.0        399     1      1
# 206045 2013-06-19    104          3   9713.0       1295     1      1
# 378669 2013-12-07    920          6   5630.0        571     1      0
# 395637 2013-12-28    963          6   4757.0        451     1      0
# ...           ...    ...        ...      ...        ...   ...    ...
# 259178 2014-10-09     57          4   9339.0        924     1      1
# 365838 2013-08-30   1114          5  24523.0       3837     1      1
# 131932 2013-06-12    532          3   9804.0       1161     1      0
# 671155 2013-07-04    823          4   4677.0        496     1      1
# 121958 2014-05-24    545          6   6893.0        673     1      0
#
#         StateHoliday  SchoolHoliday  Year  ...  StoreType  Assortment  \
# 568187             0              0  2013  ...          4           3
# 621543             0              0  2013  ...          4           3
# 206045             0              1  2013  ...          1           1
# 378669             0              0  2013  ...          1           1
# 395637             0              0  2013  ...          1           3
# ...              ...            ...   ...  ...        ...         ...
# 259178             0              0  2014  ...          4           3
# 365838             0              0  2013  ...          1           3
# 131932             0              0  2013  ...          1           3
# 671155             0              1  2013  ...          1           3
# 121958             0              0  2014  ...          1           3
#
#         CompetitionDistance  CompetitionOpenSinceMonth  \
# 568187               2870.0                        0.0
# 621543               9910.0                        0.0
# 206045                390.0                        6.0
# 378669                850.0                        2.0
# 395637              23620.0                       11.0
# ...                     ...                        ...
# 259178                420.0                        6.0
# 365838                870.0                        0.0
# 131932               1070.0                        8.0
# 671155              16210.0                       11.0
# 121958               5020.0                        5.0
#
#         CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 568187                       0.0       1             35.0           2012.0
# 621543                       0.0       0              0.0              0.0
# 206045                    2009.0       0              0.0              0.0
# 378669                    2012.0       1             40.0           2014.0
# 395637                    2013.0       0              0.0              0.0
# ...                          ...     ...              ...              ...
# 259178                    2014.0       0              0.0              0.0
# 365838                       0.0       0              0.0              0.0
# 131932                    2010.0       0              0.0              0.0
# 671155                    2010.0       0              0.0              0.0
# 121958                    2006.0       1             18.0           2014.0
#
#         CompetitionOpen  PromoOpen
# 568187          24168.0      16.25
# 621543          24158.0   24157.50
# 206045             48.0   24162.25
# 378669             22.0      -9.75
# 395637              1.0   24169.00
# ...                 ...        ...
# 259178              4.0   24178.25
# 365838          24164.0   24164.75
# 131932             34.0   24162.00
# 671155             32.0   24162.75
# 121958             96.0       0.75
#
# [585363 rows x 24 columns]

# %%
model.predict((X_train[predictors].values)[[585362]])
# Out:
# array([6770.6406], dtype=float32)

# %%
request = {
    "Store": 618,
    "DayOfWeek": 4,
    "Date": "2013-02-07",
    "Customers": 399,
    "Open": 1,
    "Promo": 1,
    "StateHoliday": "0",
    "SchoolHoliday": 0
}

# %%
date_object = datetime.strptime(request.get('Date'), '%Y-%m-%d').date()

# %%
request['Year'] = date_object.year
request['Month'] = date_object.month
request['Day'] = date_object.day

mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
state_holiday = request.get('StateHoliday')
for key, value in mappings.items():
    state_holiday = state_holiday.replace(key, str(value))
request['StateHoliday'] = int(state_holiday)

# %%
request
# Out:
# {'Store': 618,
#  'DayOfWeek': 4,
#  'Date': '2013-02-07',
#  'Customers': 399,
#  'Open': 1,
#  'Promo': 1,
#  'StateHoliday': 0,
#  'SchoolHoliday': 0,
#  'Year': 2013,
#  'Month': 2,
#  'Day': 7}

# %%
a_list = ['Store', 'DayOfWeek', 'Customers', 'Open', 'Promo', 'StateHoliday', 'SchoolHoliday', 'Year', 'Month', 'Day']
# Out:
# array([[ 618,    4,  399,    1,    1,    0,    0, 2013,    2,    7]])

# %%
# np.array([list(request.values())])

# %%
output = model.predict(np.array([[i[1] for i in [(key, request[key]) for key in a_list if key in request]]]))

# %%
output[0]
# Out:
# 5415.162
